# %%
#| hide
from Back_End.core import *

# %% [markdown]
# # Back_End
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install Back_End in Development mode

# %% [markdown]
# ```sh
# # make sure Back_End package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to Back_End
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/bthek1/Back_End.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c bthek1 Back_End
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install Back_End
# ```
#
#
# [repo]: https://github.com/bthek1/Back_End
# [docs]: https://bthek1.github.io/Back_End/
# [pypi]: https://pypi.org/project/Back_End/
# [conda]: https://anaconda.org/bthek1/Back_End

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/bthek1/Back_End
# [docs]: https://bthek1.github.io/Back_End/
# [pypi]: https://pypi.org/project/Back_End/
# [conda]: https://anaconda.org/bthek1/Back_End

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
